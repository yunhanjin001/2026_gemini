# %% [markdown]
# <a href="https://colab.research.google.com/github/yunhanjin001/2026_gemini/blob/main/code/factor_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import yfinance as yf

# %%
period = "60d"
interval = "5m"   # 分钟级（稳定）··
tech_stocks = ["AAPL", "MSFT", "NVDA", "META", "GOOGL", "AMZN"]

# ===== 黄金 =====
gold = yf.download("GC=F", period=period, interval=interval)
gold['asset'] = 'GOLD'
# Out:
# [*********************100%***********************]  1 of 1 completed
